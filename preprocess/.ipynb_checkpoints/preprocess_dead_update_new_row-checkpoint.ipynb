# %%
import numpy as np
import pandas as pd

df=pd.read_csv("dead_vital_sign_total_new_del_miss.csv")

flag=23
diff_count=0
true_total=0
change_total=0
total=0

df_new=pd.DataFrame(columns=['subject_id', 'stay_id', 'indextime','date', 'vHR', 'vRR','vsbp',
                             'vdbp','vmbp', 'vspo2', 'diffhr_index'])
my_index=0

for i in df.index :
        if(flag==df['hours_diff'][i]):
            flag=flag-1
            true_total=true_total+1
            df_new.loc[my_index] = [df['subject_id'][i],
                                    df['stay_id'][i],
                                    df['indextime'][i],
                                    df['date'][i],
                                    df['heart_rate'][i],
                                    df['resp_rate'][i],
                                    df['sbp'][i],
                                    df['dbp'][i],
                                    df['mbp'][i],
                                    df['spo2'][i],
                                    df['hours_diff'][i]]
            my_index=my_index+1           
            if (flag<0):
                   flag=23           
        else :
                total=total+1
                
                df_new.loc[my_index] = [df['subject_id'][i],
                                    df['stay_id'][i],
                                    df['indextime'][i],
                                    df['date'][i],
                                    df['heart_rate'][i],
                                    df['resp_rate'][i],
                                    df['sbp'][i],
                                    df['dbp'][i],
                                    df['mbp'][i],
                                    df['spo2'][i],
                                    df['hours_diff'][i]]
                my_index=my_index+1  
                
                if (flag!=23):
                    diff_count=(flag-df['hours_diff'][i])
                    flag=(df['hours_diff'][i])-1
                  #  print("執行的i=",i)
                  #  print(df["hours_diff"][i])
                  #  print(diff_count)
                else :
                    diff_count=(flag-df['hours_diff'][i])
                    flag=(df['hours_diff'][i])-1
                  #  print("執行的i=",i)
                  #  print(diff_count)
                if (flag<0):
                    flag=23 
                
                while(diff_count>0):                    
                        diff_count=diff_count-1                    
                        change_total=change_total+1
                        df_new.loc[my_index] = [df['subject_id'][i],
                                    df['stay_id'][i],
                                    df['indextime'][i],
                                    df['date'][i],
                                    df['heart_rate'][i],
                                    df['resp_rate'][i],
                                    df['sbp'][i],
                                    df['dbp'][i],
                                    df['mbp'][i],
                                    df['spo2'][i],
                                    df['hours_diff'][i]]
                        my_index=my_index+1  
                  
                        
print(true_total)                                               
print(total)   
print(change_total)
print(df)
print(df_new)
# Out:
# 11088
# 117
# 195
#        subject_id   stay_id         indextime              date  heart_rate  \
# 0        10026161  39625056  2133/11/15 17:55  2133/11/14 18:55          81
# 1        10026161  39625056  2133/11/15 17:55  2133/11/14 19:55          89
# 2        10026161  39625056  2133/11/15 17:55  2133/11/14 20:55          88
# 3        10026161  39625056  2133/11/15 17:55  2133/11/14 21:55          88
# 4        10026161  39625056  2133/11/15 17:55  2133/11/14 22:55          87
# ...           ...       ...               ...               ...         ...
# 11200    19993336  36483324   2171/9/29 16:01   2171/9/29 12:01          89
# 11201    19993336  36483324   2171/9/29 16:01   2171/9/29 13:01          85
# 11202    19993336  36483324   2171/9/29 16:01   2171/9/29 14:01          85
# 11203    19993336  36483324   2171/9/29 16:01   2171/9/29 15:01          85
# 11204    19993336  36483324   2171/9/29 16:01   2171/9/29 16:01          86
#
#        resp_rate    sbp   dbp   mbp  spo2  hours_diff
# 0           12.0  103.0  45.0  66.5    99          23
# 1           22.0   88.0  37.0  59.0    98          22
# 2           21.0  108.0  44.0  71.0    99          21
# 3           22.0  115.0  41.0  72.0    99          20
# 4           22.0  110.0  37.0  68.0    99          19
# ...          ...    ...   ...   ...   ...         ...
# 11200       27.0  106.0  49.0  68.0    95           4
# 11201       13.0   93.0  56.0  69.0    94           3
# 11202       22.0  104.0  55.0  71.0    95           2
# 11203       26.0   99.0  55.0  69.0    94           1
# 11204       20.0  103.0  60.0  74.0    95           0
#
# [11205 rows x 11 columns]
#       subject_id   stay_id         indextime              date vHR   vRR  \
# 0       10026161  39625056  2133/11/15 17:55  2133/11/14 18:55  81  12.0
# 1       10026161  39625056  2133/11/15 17:55  2133/11/14 19:55  89  22.0
# 2       10026161  39625056  2133/11/15 17:55  2133/11/14 20:55  88  21.0
# 3       10026161  39625056  2133/11/15 17:55  2133/11/14 21:55  88  22.0
# 4       10026161  39625056  2133/11/15 17:55  2133/11/14 22:55  87  22.0
# ...          ...       ...               ...               ...  ..   ...
# 11395   19993336  36483324   2171/9/29 16:01   2171/9/29 12:01  89  27.0
# 11396   19993336  36483324   2171/9/29 16:01   2171/9/29 13:01  85  13.0
# 11397   19993336  36483324   2171/9/29 16:01   2171/9/29 14:01  85  22.0
# 11398   19993336  36483324   2171/9/29 16:01   2171/9/29 15:01  85  26.0
# 11399   19993336  36483324   2171/9/29 16:01   2171/9/29 16:01  86  20.0
#
#         vsbp  vdbp  vmbp vspo2 diffhr_index
# 0      103.0  45.0  66.5    99           23
# 1       88.0  37.0  59.0    98           22
# 2      108.0  44.0  71.0    99           21
# 3      115.0  41.0  72.0    99           20
# 4      110.0  37.0  68.0    99           19
# ...      ...   ...   ...   ...          ...
# 11395  106.0  49.0  68.0    95            4
# 11396   93.0  56.0  69.0    94            3
# 11397  104.0  55.0  71.0    95            2
# 11398   99.0  55.0  69.0    94            1
# 11399  103.0  60.0  74.0    95            0
#
# [11400 rows x 11 columns]

# %%
df_new.to_csv("dead_vital_sign_total_new_do_new_del_miss_result.csv",index=False)
