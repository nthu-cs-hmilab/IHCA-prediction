# %%
import numpy as np
import pandas as pd

df=pd.read_csv("control_vital_sign_result.csv")

flag=23
diff_count=0
true_total=0
change_total=0
total=0

df_new=pd.DataFrame(columns=['subject_id', 'stay_id', 'indextime','date', 'vHR', 'vRR','vsbp',
                             'vdbp','vmbp', 'vspo2', 'diffhr_index'])
my_index=0

for i in df.index :
        if(flag==df['hours_diff'][i]):
            flag=flag-1
            true_total=true_total+1
            df_new.loc[my_index] = [df['subject_id'][i],
                                    df['stay_id'][i],
                                    df['indextime'][i],
                                    df['date'][i],
                                    df['heart_rate'][i],
                                    df['resp_rate'][i],
                                    df['sbp'][i],
                                    df['dbp'][i],
                                    df['mbp'][i],
                                    df['spo2'][i],
                                    df['hours_diff'][i]]
            my_index=my_index+1           
            if (flag<0):
                   flag=23           
        else :
                total=total+1
                
                df_new.loc[my_index] = [df['subject_id'][i],
                                    df['stay_id'][i],
                                    df['indextime'][i],
                                    df['date'][i],
                                    df['heart_rate'][i],
                                    df['resp_rate'][i],
                                    df['sbp'][i],
                                    df['dbp'][i],
                                    df['mbp'][i],
                                    df['spo2'][i],
                                    df['hours_diff'][i]]
                my_index=my_index+1  
                
                if (flag!=23):
                    diff_count=(flag-df['hours_diff'][i])
                    flag=(df['hours_diff'][i])-1
                  #  print("執行的i=",i)
                  #  print(df["hours_diff"][i])
                  #  print(diff_count)
                else :
                    diff_count=(flag-df['hours_diff'][i])
                    flag=(df['hours_diff'][i])-1
                  #  print("執行的i=",i)
                  #  print(diff_count)
                if (flag<0):
                    flag=23 
                
                while(diff_count>0):                    
                        diff_count=diff_count-1                    
                        change_total=change_total+1
                        df_new.loc[my_index] = [df['subject_id'][i],
                                    df['stay_id'][i],
                                    df['indextime'][i],
                                    df['date'][i],
                                    df['heart_rate'][i],
                                    df['resp_rate'][i],
                                    df['sbp'][i],
                                    df['dbp'][i],
                                    df['mbp'][i],
                                    df['spo2'][i],
                                    df['hours_diff'][i]]
                        my_index=my_index+1  
                  
                        
print(true_total)                                               
print(total)   
print(change_total)
print(df)
print(df_new)
# Out:
# 0
# 0
# 0
# Empty DataFrame
# Columns: [subject_id, stay_id, indextime, date, heart_rate, resp_rate, sbp, dbp, mbp, spo2, hours_diff]
# Index: []
# Empty DataFrame
# Columns: [subject_id, stay_id, indextime, date, vHR, vRR, vsbp, vdbp, vmbp, vspo2, diffhr_index]
# Index: []
