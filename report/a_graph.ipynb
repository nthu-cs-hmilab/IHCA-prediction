# %%
import numpy as np
import matplotlib.pyplot as plt
import shutil
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import os
import numpy as np

a = np.random.normal(0, 3, 3000)
b = np.random.normal(2, 4, 2000)
c = np.random.normal(4, 6, 2000)

bins = np.linspace(-10, 10, 10)

plt.hist([a, b,c], bins, label=['a', 'b','c'])
plt.legend(loc='upper left')
plt.show()

# %%
ca=pd.read_csv("mimic_ca_baseline.csv")
dead=pd.read_csv("mimic_dead_baseline.csv")
control=pd.read_csv("mimic_control_baseline.csv")

# %%
ca_f=ca['age']
dead_f=dead['age']
control_f=control['age']

# %%
age_bins = np.linspace(20, 90, 20)

plt.hist([ca_f,control_f], age_bins, label=['Ca','Control'])
plt.legend(loc='upper left')
plt.show()

# %%
age_bins = np.linspace(20, 90, 20)

plt.hist([ca_f], age_bins, label=['Ca'])
plt.legend(loc='upper left')
plt.show()

# %%
age_bins = np.linspace(20, 90, 20)

plt.hist([dead_f], age_bins, label=['Death'])
plt.legend(loc='upper left')
plt.show()

# %%
age_bins = np.linspace(20, 90, 20)

plt.hist([control_f], age_bins, label=['Control'])
plt.legend(loc='upper left')
plt.show()

# %%
age_bins
# Out:
# array([ 0.        ,  8.88888889, 17.77777778, 26.66666667, 35.55555556,
#        44.44444444, 53.33333333, 62.22222222, 71.11111111, 80.        ])

# %%
print(bins)
# Out:
# [-10.          -7.77777778  -5.55555556  -3.33333333  -1.11111111
#    1.11111111   3.33333333   5.55555556   7.77777778  10.        ]

# %%
print(a)
# Out:
# [-3.87849103 -3.51244257 -0.77343885 ...  2.22719384 -3.74957965
#   3.64857248]

# %%
print(b)
# Out:
# [ 2.79739012  5.1785652  12.1095282  ...  2.0553908   0.4753731
#  -0.26785071]
