# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt   # plotting
import seaborn as sns   # plotting heatmap

import keras 
import tensorflow as tf
from sklearn import preprocessing  #用來標準化刻度
from keras.models import Sequential
from keras.layers import Dense,Dropout  
from sklearn.model_selection import train_test_split
from keras.losses import logcosh, categorical_crossentropy
from keras.utils import to_categorical
from scipy import interp
from itertools import cycle
from sklearn import svm, datasets
from sklearn.metrics import roc_curve, auc
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import label_binarize
from sklearn.multiclass import OneVsRestClassifier
from scipy import interp
from sklearn.metrics import roc_auc_score

time=21
to_time=time-1

df_ca_train=pd.read_csv("mimic_ca_vital_sign_combine_train_"+str(time)+"hours.csv")
df_ca_test=pd.read_csv("mimic_ca_vital_sign_combine_test_"+str(time)+"hours.csv")

df_dead_train=pd.read_csv("mimic_dead_vital_sign_combine_train_"+str(time)+"hours.csv")
df_dead_test=pd.read_csv("mimic_dead_vital_sign_combine_test_"+str(time)+"hours.csv")

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

#######################殺資料###############################
flag_ca_train=df_ca_train.shape[0] 
flag_ca_test=df_ca_test.shape[0]  

flag_dead_train=df_dead_train.shape[0] 
flag_dead_test=df_dead_test.shape[0] 

for i in range(flag_ca_train): 
      if i%time== to_time: 
         df_ca_train=df_ca_train.drop([i])
        
for i in range(flag_ca_test): 
      if i%time== to_time: 
         df_ca_test=df_ca_test.drop([i])
        
for i in range(flag_dead_train): 
      if i%time== to_time: 
         df_dead_train=df_dead_train.drop([i])
        
for i in range(flag_dead_test): 
      if i%time== to_time: 
         df_dead_test=df_dead_test.drop([i])
###########################################################

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

df_ca_train.to_csv('mimic_ca_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_ca_test.to_csv('mimic_ca_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
df_dead_train.to_csv('mimic_dead_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_dead_test.to_csv('mimic_dead_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
# Out:
# Using TensorFlow backend.
# (452340, 70)
# (113064, 70)
# 452340
# 113064
# (506100, 70)
# (126525, 70)
# 506100
# 126525
# (430800, 70)
# (107680, 70)
# 430800
# 107680
# (482000, 70)
# (120500, 70)
# 482000
# 120500

# %%
time=time-1
to_time=time-1

df_ca_train=pd.read_csv("mimic_ca_vital_sign_combine_train_"+str(time)+"hours.csv")
df_ca_test=pd.read_csv("mimic_ca_vital_sign_combine_test_"+str(time)+"hours.csv")

df_dead_train=pd.read_csv("mimic_dead_vital_sign_combine_train_"+str(time)+"hours.csv")
df_dead_test=pd.read_csv("mimic_dead_vital_sign_combine_test_"+str(time)+"hours.csv")

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

#######################殺資料###############################
flag_ca_train=df_ca_train.shape[0] 
flag_ca_test=df_ca_test.shape[0]  

flag_dead_train=df_dead_train.shape[0] 
flag_dead_test=df_dead_test.shape[0] 

for i in range(flag_ca_train): 
      if i%time== to_time: 
         df_ca_train=df_ca_train.drop([i])
        
for i in range(flag_ca_test): 
      if i%time== to_time: 
         df_ca_test=df_ca_test.drop([i])
        
for i in range(flag_dead_train): 
      if i%time== to_time: 
         df_dead_train=df_dead_train.drop([i])
        
for i in range(flag_dead_test): 
      if i%time== to_time: 
         df_dead_test=df_dead_test.drop([i])
###########################################################

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

df_ca_train.to_csv('mimic_ca_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_ca_test.to_csv('mimic_ca_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
df_dead_train.to_csv('mimic_dead_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_dead_test.to_csv('mimic_dead_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
# Out:
# (430800, 70)
# (107680, 70)
# 430800
# 107680
# (482000, 70)
# (120500, 70)
# 482000
# 120500
# (409260, 70)
# (102296, 70)
# 409260
# 102296
# (457900, 70)
# (114475, 70)
# 457900
# 114475

# %%
time=time-1
to_time=time-1

df_ca_train=pd.read_csv("mimic_ca_vital_sign_combine_train_"+str(time)+"hours.csv")
df_ca_test=pd.read_csv("mimic_ca_vital_sign_combine_test_"+str(time)+"hours.csv")

df_dead_train=pd.read_csv("mimic_dead_vital_sign_combine_train_"+str(time)+"hours.csv")
df_dead_test=pd.read_csv("mimic_dead_vital_sign_combine_test_"+str(time)+"hours.csv")

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

#######################殺資料###############################
flag_ca_train=df_ca_train.shape[0] 
flag_ca_test=df_ca_test.shape[0]  

flag_dead_train=df_dead_train.shape[0] 
flag_dead_test=df_dead_test.shape[0] 

for i in range(flag_ca_train): 
      if i%time== to_time: 
         df_ca_train=df_ca_train.drop([i])
        
for i in range(flag_ca_test): 
      if i%time== to_time: 
         df_ca_test=df_ca_test.drop([i])
        
for i in range(flag_dead_train): 
      if i%time== to_time: 
         df_dead_train=df_dead_train.drop([i])
        
for i in range(flag_dead_test): 
      if i%time== to_time: 
         df_dead_test=df_dead_test.drop([i])
###########################################################

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

df_ca_train.to_csv('mimic_ca_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_ca_test.to_csv('mimic_ca_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
df_dead_train.to_csv('mimic_dead_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_dead_test.to_csv('mimic_dead_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
# Out:
# (409260, 70)
# (102296, 70)
# 409260
# 102296
# (457900, 70)
# (114475, 70)
# 457900
# 114475
# (387720, 70)
# (96912, 70)
# 387720
# 96912
# (433800, 70)
# (108450, 70)
# 433800
# 108450

# %%
time=time-1
to_time=time-1

df_ca_train=pd.read_csv("mimic_ca_vital_sign_combine_train_"+str(time)+"hours.csv")
df_ca_test=pd.read_csv("mimic_ca_vital_sign_combine_test_"+str(time)+"hours.csv")

df_dead_train=pd.read_csv("mimic_dead_vital_sign_combine_train_"+str(time)+"hours.csv")
df_dead_test=pd.read_csv("mimic_dead_vital_sign_combine_test_"+str(time)+"hours.csv")

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

#######################殺資料###############################
flag_ca_train=df_ca_train.shape[0] 
flag_ca_test=df_ca_test.shape[0]  

flag_dead_train=df_dead_train.shape[0] 
flag_dead_test=df_dead_test.shape[0] 

for i in range(flag_ca_train): 
      if i%time== to_time: 
         df_ca_train=df_ca_train.drop([i])
        
for i in range(flag_ca_test): 
      if i%time== to_time: 
         df_ca_test=df_ca_test.drop([i])
        
for i in range(flag_dead_train): 
      if i%time== to_time: 
         df_dead_train=df_dead_train.drop([i])
        
for i in range(flag_dead_test): 
      if i%time== to_time: 
         df_dead_test=df_dead_test.drop([i])
###########################################################

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

df_ca_train.to_csv('mimic_ca_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_ca_test.to_csv('mimic_ca_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
df_dead_train.to_csv('mimic_dead_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_dead_test.to_csv('mimic_dead_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
# Out:
# (387720, 70)
# (96912, 70)
# 387720
# 96912
# (433800, 70)
# (108450, 70)
# 433800
# 108450
# (366180, 70)
# (91528, 70)
# 366180
# 91528
# (409700, 70)
# (102425, 70)
# 409700
# 102425

# %%
time=time-1
to_time=time-1

df_ca_train=pd.read_csv("mimic_ca_vital_sign_combine_train_"+str(time)+"hours.csv")
df_ca_test=pd.read_csv("mimic_ca_vital_sign_combine_test_"+str(time)+"hours.csv")

df_dead_train=pd.read_csv("mimic_dead_vital_sign_combine_train_"+str(time)+"hours.csv")
df_dead_test=pd.read_csv("mimic_dead_vital_sign_combine_test_"+str(time)+"hours.csv")

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

#######################殺資料###############################
flag_ca_train=df_ca_train.shape[0] 
flag_ca_test=df_ca_test.shape[0]  

flag_dead_train=df_dead_train.shape[0] 
flag_dead_test=df_dead_test.shape[0] 

for i in range(flag_ca_train): 
      if i%time== to_time: 
         df_ca_train=df_ca_train.drop([i])
        
for i in range(flag_ca_test): 
      if i%time== to_time: 
         df_ca_test=df_ca_test.drop([i])
        
for i in range(flag_dead_train): 
      if i%time== to_time: 
         df_dead_train=df_dead_train.drop([i])
        
for i in range(flag_dead_test): 
      if i%time== to_time: 
         df_dead_test=df_dead_test.drop([i])
###########################################################

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

df_ca_train.to_csv('mimic_ca_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_ca_test.to_csv('mimic_ca_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
df_dead_train.to_csv('mimic_dead_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_dead_test.to_csv('mimic_dead_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
# Out:
# (366180, 70)
# (91528, 70)
# 366180
# 91528
# (409700, 70)
# (102425, 70)
# 409700
# 102425
# (344640, 70)
# (86144, 70)
# 344640
# 86144
# (385600, 70)
# (96400, 70)
# 385600
# 96400

# %%
time=time-1
to_time=time-1

df_ca_train=pd.read_csv("mimic_ca_vital_sign_combine_train_"+str(time)+"hours.csv")
df_ca_test=pd.read_csv("mimic_ca_vital_sign_combine_test_"+str(time)+"hours.csv")

df_dead_train=pd.read_csv("mimic_dead_vital_sign_combine_train_"+str(time)+"hours.csv")
df_dead_test=pd.read_csv("mimic_dead_vital_sign_combine_test_"+str(time)+"hours.csv")

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

#######################殺資料###############################
flag_ca_train=df_ca_train.shape[0] 
flag_ca_test=df_ca_test.shape[0]  

flag_dead_train=df_dead_train.shape[0] 
flag_dead_test=df_dead_test.shape[0] 

for i in range(flag_ca_train): 
      if i%time== to_time: 
         df_ca_train=df_ca_train.drop([i])
        
for i in range(flag_ca_test): 
      if i%time== to_time: 
         df_ca_test=df_ca_test.drop([i])
        
for i in range(flag_dead_train): 
      if i%time== to_time: 
         df_dead_train=df_dead_train.drop([i])
        
for i in range(flag_dead_test): 
      if i%time== to_time: 
         df_dead_test=df_dead_test.drop([i])
###########################################################

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

df_ca_train.to_csv('mimic_ca_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_ca_test.to_csv('mimic_ca_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
df_dead_train.to_csv('mimic_dead_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_dead_test.to_csv('mimic_dead_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
# Out:
# (344640, 70)
# (86144, 70)
# 344640
# 86144
# (385600, 70)
# (96400, 70)
# 385600
# 96400
# (323100, 70)
# (80760, 70)
# 323100
# 80760
# (361500, 70)
# (90375, 70)
# 361500
# 90375

# %%
time=time-1
to_time=time-1

df_ca_train=pd.read_csv("mimic_ca_vital_sign_combine_train_"+str(time)+"hours.csv")
df_ca_test=pd.read_csv("mimic_ca_vital_sign_combine_test_"+str(time)+"hours.csv")

df_dead_train=pd.read_csv("mimic_dead_vital_sign_combine_train_"+str(time)+"hours.csv")
df_dead_test=pd.read_csv("mimic_dead_vital_sign_combine_test_"+str(time)+"hours.csv")

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

#######################殺資料###############################
flag_ca_train=df_ca_train.shape[0] 
flag_ca_test=df_ca_test.shape[0]  

flag_dead_train=df_dead_train.shape[0] 
flag_dead_test=df_dead_test.shape[0] 

for i in range(flag_ca_train): 
      if i%time== to_time: 
         df_ca_train=df_ca_train.drop([i])
        
for i in range(flag_ca_test): 
      if i%time== to_time: 
         df_ca_test=df_ca_test.drop([i])
        
for i in range(flag_dead_train): 
      if i%time== to_time: 
         df_dead_train=df_dead_train.drop([i])
        
for i in range(flag_dead_test): 
      if i%time== to_time: 
         df_dead_test=df_dead_test.drop([i])
###########################################################

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

df_ca_train.to_csv('mimic_ca_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_ca_test.to_csv('mimic_ca_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
df_dead_train.to_csv('mimic_dead_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_dead_test.to_csv('mimic_dead_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
# Out:
# (323100, 70)
# (80760, 70)
# 323100
# 80760
# (361500, 70)
# (90375, 70)
# 361500
# 90375
# (301560, 70)
# (75376, 70)
# 301560
# 75376
# (337400, 70)
# (84350, 70)
# 337400
# 84350

# %%
time=time-1
to_time=time-1

df_ca_train=pd.read_csv("mimic_ca_vital_sign_combine_train_"+str(time)+"hours.csv")
df_ca_test=pd.read_csv("mimic_ca_vital_sign_combine_test_"+str(time)+"hours.csv")

df_dead_train=pd.read_csv("mimic_dead_vital_sign_combine_train_"+str(time)+"hours.csv")
df_dead_test=pd.read_csv("mimic_dead_vital_sign_combine_test_"+str(time)+"hours.csv")

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

#######################殺資料###############################
flag_ca_train=df_ca_train.shape[0] 
flag_ca_test=df_ca_test.shape[0]  

flag_dead_train=df_dead_train.shape[0] 
flag_dead_test=df_dead_test.shape[0] 

for i in range(flag_ca_train): 
      if i%time== to_time: 
         df_ca_train=df_ca_train.drop([i])
        
for i in range(flag_ca_test): 
      if i%time== to_time: 
         df_ca_test=df_ca_test.drop([i])
        
for i in range(flag_dead_train): 
      if i%time== to_time: 
         df_dead_train=df_dead_train.drop([i])
        
for i in range(flag_dead_test): 
      if i%time== to_time: 
         df_dead_test=df_dead_test.drop([i])
###########################################################

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

df_ca_train.to_csv('mimic_ca_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_ca_test.to_csv('mimic_ca_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
df_dead_train.to_csv('mimic_dead_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_dead_test.to_csv('mimic_dead_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
# Out:
# (301560, 70)
# (75376, 70)
# 301560
# 75376
# (337400, 70)
# (84350, 70)
# 337400
# 84350
# (280020, 70)
# (69992, 70)
# 280020
# 69992
# (313300, 70)
# (78325, 70)
# 313300
# 78325

# %%
time=time-1
to_time=time-1

df_ca_train=pd.read_csv("mimic_ca_vital_sign_combine_train_"+str(time)+"hours.csv")
df_ca_test=pd.read_csv("mimic_ca_vital_sign_combine_test_"+str(time)+"hours.csv")

df_dead_train=pd.read_csv("mimic_dead_vital_sign_combine_train_"+str(time)+"hours.csv")
df_dead_test=pd.read_csv("mimic_dead_vital_sign_combine_test_"+str(time)+"hours.csv")

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

#######################殺資料###############################
flag_ca_train=df_ca_train.shape[0] 
flag_ca_test=df_ca_test.shape[0]  

flag_dead_train=df_dead_train.shape[0] 
flag_dead_test=df_dead_test.shape[0] 

for i in range(flag_ca_train): 
      if i%time== to_time: 
         df_ca_train=df_ca_train.drop([i])
        
for i in range(flag_ca_test): 
      if i%time== to_time: 
         df_ca_test=df_ca_test.drop([i])
        
for i in range(flag_dead_train): 
      if i%time== to_time: 
         df_dead_train=df_dead_train.drop([i])
        
for i in range(flag_dead_test): 
      if i%time== to_time: 
         df_dead_test=df_dead_test.drop([i])
###########################################################

print(df_ca_train.shape)
print(df_ca_test.shape)
print(df_ca_train.shape[0])
print(df_ca_test.shape[0])

print(df_dead_train.shape)
print(df_dead_test.shape)
print(df_dead_train.shape[0])
print(df_dead_test.shape[0])

df_ca_train.to_csv('mimic_ca_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_ca_test.to_csv('mimic_ca_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
df_dead_train.to_csv('mimic_dead_vital_sign_combine_train_'+str(to_time)+'hours.csv', index=False)
df_dead_test.to_csv('mimic_dead_vital_sign_combine_test_'+str(to_time)+'hours.csv', index=False)
# Out:
# (280020, 70)
# (69992, 70)
# 280020
# 69992
# (313300, 70)
# (78325, 70)
# 313300
# 78325
# (258480, 70)
# (64608, 70)
# 258480
# 64608
# (289200, 70)
# (72300, 70)
# 289200
# 72300
